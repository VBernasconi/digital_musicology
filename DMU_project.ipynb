# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_billboard = pd.read_csv(
    'data/Billboard-Weekly-Songs-With-Song-And-Artist-Spotify-Popularity.csv')
df_dataset = pd.read_csv('data/dataset.csv').drop(columns = 'Unnamed: 0')
df_artist_genres = pd.read_csv('data/artists_genres.csv')

# %%
df_billboard.head()
# Out:
#          date  Rank              Title                              Artist  \
# 0  1955-01-01     1   Poor Little Fool                        Ricky Nelson
# 1  1955-01-01     2           Patricia       Perez Prado And His Orchestra
# 2  1955-01-01     3      Splish Splash                         Bobby Darin
# 3  1955-01-01     4  Hard Headed Woman  Elvis Presley With The Jordanaires
# 4  1955-01-01     5               When                         Kalin Twins
#
#    Weeks on chart  year  Spotify_Popularity  Artist_Popularity
# 0             1.0  1955                  -1                 56
# 1             NaN  1955                  -1                 12
# 2             NaN  1955                  -1                 62
# 3             NaN  1955                  -1                 -1
# 4             NaN  1955                  -1                 24

# %%
df_dataset.head()
# Out:
#                Title                              Artist  Weeks on chart  \
# 0   Poor Little Fool                        Ricky Nelson             1.0
# 1           Patricia       Perez Prado And His Orchestra             NaN
# 2      Splish Splash                         Bobby Darin             NaN
# 3  Hard Headed Woman  Elvis Presley With The Jordanaires             NaN
# 4               When                         Kalin Twins             NaN
#
#    year  Spotify_Popularity  Artist_Popularity                track_id  \
# 0  1955                  -1                 56  5ayybTSXNwcarDtxQKqvWX
# 1  1955                  -1                 12  205EtD8tQnHDXMkmtYiaHF
# 2  1955                  -1                 62  40fD7ct05FvQHLdQTgJelG
# 3  1955                  -1                 -1  32CVurlBxtEYQlDm3yzCLl
# 4  1955                  -1                 24  1BQOMZeYwzesvXANmRgrEp
#
#                      track_title   track_artist  danceability  ...   loudness  \
# 0  Poor Little Fool - Remastered   Ricky Nelson         0.543  ...    -11.573
# 1                       Patricia    Pérez Prado         0.704  ...     -9.522
# 2                  Splish Splash    Bobby Darin         0.645  ...     -1.526
# 3              Hard Headed Woman  Elvis Presley         0.610  ...     -8.739
# 4                    When - Live    Kalin Twins         0.646  ...    -12.679
#
#    speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       0.0317        0.6690          0.000000     0.134    0.795
# 1       0.0457        0.0862          0.251000     0.115    0.837
# 2       0.0393        0.3850          0.000000     0.370    0.965
# 3       0.1760        0.8420          0.000002     0.501    0.859
# 4       0.0297        0.1680          0.000005     0.976    0.963
#
#    duration_ms  time_signature    tempo  mode
# 0     153933.0             4.0  154.999   1.0
# 1     140867.0             4.0  137.396   1.0
# 2     131720.0             4.0  147.768   1.0
# 3     113480.0             4.0   97.924   1.0
# 4     144573.0             4.0   96.490   1.0
#
# [5 rows x 22 columns]

# %%
len(df_billboard)
# Out:
# 300600

# %%
df_dataset.columns
# Out:
# Index(['Title', 'Artist', 'Weeks on chart', 'year', 'Spotify_Popularity',
#        'Artist_Popularity', 'track_id', 'track_title', 'track_artist',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence',
#        'duration_ms', 'time_signature', 'tempo', 'mode'],
#       dtype='object')
