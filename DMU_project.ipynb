# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_billboard = pd.read_csv(
    'data/Billboard-Weekly-Songs-With-Song-And-Artist-Spotify-Popularity.csv').drop(
    columns = 'Unnamed: 0')
df_dataset = pd.read_csv('data/dataset.csv')
df_artist_genres = pd.read_csv('data/artists_genres.csv')

# %%
df_billboard.head()
# Out:
#          date  Rank              Title                              Artist  \
# 0  1955-01-01     1   Poor Little Fool                        Ricky Nelson
# 1  1955-01-01     2           Patricia       Perez Prado And His Orchestra
# 2  1955-01-01     3      Splish Splash                         Bobby Darin
# 3  1955-01-01     4  Hard Headed Woman  Elvis Presley With The Jordanaires
# 4  1955-01-01     5               When                         Kalin Twins
#
#    Weeks on chart  year  Spotify_Popularity  Artist_Popularity
# 0             1.0  1955                  -1                 56
# 1             NaN  1955                  -1                 12
# 2             NaN  1955                  -1                 62
# 3             NaN  1955                  -1                 -1
# 4             NaN  1955                  -1                 24

# %%
len(df_billboard)
# Out:
# 300600

# %%
df_dataset.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Artist', 'Weeks on chart', 'year',
#        'Spotify_Popularity', 'Artist_Popularity', 'track_id', 'track_title',
#        'track_artist', 'danceability', 'energy', 'key', 'loudness',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'duration_ms', 'time_signature', 'tempo', 'mode'],
#       dtype='object')

# %%
df_dataset.head()
# Out:
#    Unnamed: 0.1              Title                              Artist  \
# 0             0   Poor Little Fool                        Ricky Nelson
# 1             1           Patricia       Perez Prado And His Orchestra
# 2             2      Splish Splash                         Bobby Darin
# 3             3  Hard Headed Woman  Elvis Presley With The Jordanaires
# 4             4               When                         Kalin Twins
#
#    Weeks on chart  year  Spotify_Popularity  Artist_Popularity  \
# 0             1.0  1955                  -1                 56
# 1             NaN  1955                  -1                 12
# 2             NaN  1955                  -1                 62
# 3             NaN  1955                  -1                 -1
# 4             NaN  1955                  -1                 24
#
#                  track_id                    track_title   track_artist  ...   \
# 0  5ayybTSXNwcarDtxQKqvWX  Poor Little Fool - Remastered   Ricky Nelson  ...
# ...
